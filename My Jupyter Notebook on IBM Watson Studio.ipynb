# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Saeed Makaremi**
# Urban Data Scientist

# %% [markdown]
# *I am interested in data science because it's an essential in my career as an urban data scientist.

# %% [markdown]
# ### My code is going to multiple 2 with 2

# %%
print (2*2)
# Out:
# 4

# %% [markdown]
# ~~This was mistaken text~~
#
# > Text that is a quote
#
# | Age  | Gender |
# | ---- | ------ |
# |  26  |  Male  |
# |  24  | Female |
#
# ![This is an image](https://myoctocat.com/assets/images/base-octocat.svg)
